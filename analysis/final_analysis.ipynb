# %%
import pandas as pd

# %%
analysis_df = pd.read_csv('./ecir_res/union_output_v0.csv')

# %%
gpp_df = analysis_df[analysis_df['Prediction Name']=='GPP']
rpp_df = analysis_df[analysis_df['Prediction Name']=='RPP']

# %%
rpp_df.query('Use_Postgen==True')
# Out:
#    Prediction Name QA Task Retriever  Top-Retrieved Docs  Use_Postgen  \
# 28             RPP      dl      bm25                   3         True
# 29             RPP      dl      bm25                   3         True
# 30             RPP      dl      bm25                   3         True
# 31             RPP      dl      bm25                   3         True
# 36             RPP      dl        e5                   3         True
# 37             RPP      dl        e5                   3         True
# 38             RPP      dl        e5                   3         True
# 39             RPP      dl        e5                   3         True
# 44             RPP      dl       mt5                   3         True
# 45             RPP      dl       mt5                   3         True
# 46             RPP      dl       mt5                   3         True
# 47             RPP      dl       mt5                   3         True
# 52             RPP      nq       mt5                   3         True
# 53             RPP      nq       mt5                   3         True
# 54             RPP      nq       mt5                   3         True
# 55             RPP      nq       mt5                   3         True
# 60             RPP      nq        e5                   3         True
# 61             RPP      nq        e5                   3         True
# 62             RPP      nq        e5                   3         True
# 63             RPP      nq        e5                   3         True
# 68             RPP      nq      bm25                   3         True
# 69             RPP      nq      bm25                   3         True
# 70             RPP      nq      bm25                   3         True
# 71             RPP      nq      bm25                   3         True
#
#     Combination_Number       Rho       Tau Best Single Signal  \
# 28                   0  0.389254  0.263746            prob(k)
# 29                   1  0.400642  0.277062            prob(k)
# 30                   2  0.392423  0.267612            prob(k)
# 31                   3  0.391687  0.266323            prob(k)
# 36                   0  0.246305  0.170103           maxScore
# 37                   1  0.271079  0.189003           maxScore
# 38                   2  0.271329  0.190722           maxScore
# 39                   3  0.268160  0.188144           maxScore
# 44                   0  0.480473  0.341924            prob(k)
# 45                   1  0.481341  0.348797            prob(k)
# 46                   2  0.485009  0.344931            prob(k)
# 47                   3  0.482090  0.336770            prob(k)
# 52                   0  0.221769  0.163080           maxScore
# 53                   1  0.223896  0.164525           maxScore
# 54                   2  0.227716  0.167313           maxScore
# 55                   3  0.232367  0.170624           maxScore
# 60                   0  0.252621  0.186282            prob(k)
# 61                   1  0.247281  0.182136            prob(k)
# 62                   2  0.246713  0.181726            prob(k)
# 63                   3  0.244484  0.180091            prob(k)
# 68                   0  0.249277  0.184624            bertQPP
# 69                   1  0.251253  0.185921            bertQPP
# 70                   2  0.251706  0.186300            bertQPP
# 71                   3  0.249558  0.184619            bertQPP
#
#     Best Single Rho  Best Single Tau
# 28           0.3345           0.2281
# 29           0.3345           0.2281
# 30           0.3345           0.2281
# 31           0.3345           0.2281
# 36           0.3076           0.2113
# 37           0.3076           0.2113
# 38           0.3076           0.2113
# 39           0.3076           0.2113
# 44           0.4441           0.3114
# 45           0.4441           0.3114
# 46           0.4441           0.3114
# 47           0.4441           0.3114
# 52           0.1770           0.1305
# 53           0.1770           0.1305
# 54           0.1770           0.1305
# 55           0.1770           0.1305
# 60           0.1643           0.1210
# 61           0.1643           0.1210
# 62           0.1643           0.1210
# 63           0.1643           0.1210
# 68           0.1881           0.1393
# 69           0.1881           0.1393
# 70           0.1881           0.1393
# 71           0.1881           0.1393
