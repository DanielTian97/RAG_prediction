# %%
import pandas as pd

# %%
df = pd.read_csv('./result_qpp_union/bm25_3.csv')
df = df[((df.alpha==0)|(df.alpha==0.5)|(df.alpha==1))&(df.window_size==10)]

# %%
df[df.alpha==0].sort_values(by=['tau'], ascending=False)
# Out:
#      retriever  k   qpp_method  window_size  alpha         r     p1(r)  \
# 1683      bm25  3      a_ratio           10    0.0  0.438169  0.000007
# 1681      bm25  3      spatial           10    0.0  0.354755  0.000363
# 1687      bm25  3      bertQPP           10    0.0  0.329410  0.000985
# 1689      bm25  3  bertQPP(QV)           10    0.0  0.342484  0.000595
# 1680      bm25  3      spatial           10    0.0  0.384525  0.000101
# 1686      bm25  3      bertQPP           10    0.0  0.255573  0.011518
# 1688      bm25  3  bertQPP(QV)           10    0.0  0.247476  0.014529
# 1682      bm25  3      a_ratio           10    0.0  0.313620  0.001760
# 1685      bm25  3          nqc           10    0.0  0.122510  0.231911
# 1684      bm25  3          nqc           10    0.0  0.015030  0.883825
#
#            tau   p1(tau)  num_of_queries  with_0shot_posterior
# 1683  0.292526  0.000022              97                  True
# 1681  0.279639  0.000050              97                  True
# 1687  0.224656  0.001114              97                  True
# 1689  0.220790  0.001356              97                  True
# 1680  0.219931  0.001416              97                 False
# 1686  0.186856  0.006698              97                 False
# 1688  0.185567  0.007086              97                 False
# 1682  0.120704  0.079850              97                 False
# 1685  0.045962  0.504796              97                  True
# 1684 -0.023625  0.731725              97                 False

# %%
df[(df.alpha==0.5)&(df.with_0shot_posterior==True)]
# Out:
#      retriever  k   qpp_method  window_size  alpha         r     p1(r)  \
# 1781      bm25  3      spatial           10    0.5  0.360167  0.000290
# 1783      bm25  3      a_ratio           10    0.5  0.439018  0.000007
# 1785      bm25  3          nqc           10    0.5  0.137730  0.178522
# 1787      bm25  3      bertQPP           10    0.5  0.398588  0.000053
# 1789      bm25  3  bertQPP(QV)           10    0.5  0.408793  0.000032
#
#            tau   p1(tau)  num_of_queries  with_0shot_posterior
# 1781  0.288660  0.000028              97                  True
# 1783  0.308849  0.000007              97                  True
# 1785  0.062285  0.366086              97                  True
# 1787  0.233247  0.000713              97                  True
# 1789  0.246134  0.000355              97                  True

# %%
df[df.with_0shot_posterior==False].sort_values(by=['tau'], ascending=False).head(5)
# Out:
#      retriever  k   qpp_method  window_size  alpha         r     p1(r)  \
# 1680      bm25  3      spatial           10    0.0  0.384525  0.000101
# 1780      bm25  3      spatial           10    0.5  0.334352  0.000816
# 1786      bm25  3      bertQPP           10    0.5  0.316656  0.001578
# 1788      bm25  3  bertQPP(QV)           10    0.5  0.313565  0.001763
# 1686      bm25  3      bertQPP           10    0.0  0.255573  0.011518
#
#            tau   p1(tau)  num_of_queries  with_0shot_posterior
# 1680  0.219931  0.001416              97                 False
# 1780  0.201460  0.003462              97                 False
# 1786  0.192010  0.005332              97                 False
# 1788  0.190292  0.005756              97                 False
# 1686  0.186856  0.006698              97                 False

# %%
df[df.with_0shot_posterior].sort_values(by=['tau'], ascending=False).head(5)
# Out:
#      retriever  k   qpp_method  window_size  alpha         r     p1(r)  \
# 1783      bm25  3      a_ratio           10    0.5  0.439018  0.000007
# 1683      bm25  3      a_ratio           10    0.0  0.438169  0.000007
# 1781      bm25  3      spatial           10    0.5  0.360167  0.000290
# 1681      bm25  3      spatial           10    0.0  0.354755  0.000363
# 1789      bm25  3  bertQPP(QV)           10    0.5  0.408793  0.000032
#
#            tau   p1(tau)  num_of_queries  with_0shot_posterior
# 1783  0.308849  0.000007              97                  True
# 1683  0.292526  0.000022              97                  True
# 1781  0.288660  0.000028              97                  True
# 1681  0.279639  0.000050              97                  True
# 1789  0.246134  0.000355              97                  True

# %%
df[(df.alpha==0)&(df.window_size==10)&(df.with_0shot_posterior==False)]
# Out:
#      retriever  k   qpp_method  window_size  alpha         r     p1(r)  \
# 1680      bm25  3      spatial           10    0.0  0.384525  0.000101
# 1682      bm25  3      a_ratio           10    0.0  0.313620  0.001760
# 1684      bm25  3          nqc           10    0.0  0.015030  0.883825
# 1686      bm25  3      bertQPP           10    0.0  0.255573  0.011518
# 1688      bm25  3  bertQPP(QV)           10    0.0  0.247476  0.014529
#
#            tau   p1(tau)  num_of_queries  with_0shot_posterior
# 1680  0.219931  0.001416              97                 False
# 1682  0.120704  0.079850              97                 False
# 1684 -0.023625  0.731725              97                 False
# 1686  0.186856  0.006698              97                 False
# 1688  0.185567  0.007086              97                 False

# %%
df[(df.alpha==0)&(df.window_size==2)&(df.with_0shot_posterior)]
# Out:
# Empty DataFrame
# Columns: [retriever, k, qpp_method, window_size, alpha, r, p1(r), tau, p1(tau), num_of_queries, with_0shot_posterior]
# Index: []

# %%
df[(df.alpha==1)&(df.qpp_method=='spatial')&(df.with_0shot_posterior==False)]
# Out:
#      retriever  k qpp_method  window_size  alpha         r     p1(r)  \
# 1880      bm25  3    spatial           10    1.0  0.182392  0.073761
#
#            tau   p1(tau)  num_of_queries  with_0shot_posterior
# 1880  0.137027  0.046765              97                 False

# %%
df[(df.alpha==1)&(df.qpp_method=='spatial')&(df.with_0shot_posterior)]
# Out:
#      retriever  k qpp_method  window_size  alpha         r     p1(r)  \
# 1881      bm25  3    spatial           10    1.0  0.231417  0.022566
#
#            tau   p1(tau)  num_of_queries  with_0shot_posterior
# 1881  0.181701  0.008372              97                  True
