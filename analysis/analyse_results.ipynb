# %%
import pandas as pd

# %%
df = pd.read_csv('./result_qpp_union/tct_10.csv')

# %%
df.sort_values(by=['tau'], ascending=False).head(5)
# Out:
#     retriever   k qpp_method  window_size  alpha         r     p1(r)  \
# 188       tct  10    bertQPP            2   0.74  0.462407  0.000002
# 198       tct  10    bertQPP            2   0.78  0.458590  0.000002
# 203       tct  10    bertQPP            2   0.80  0.454819  0.000003
# 183       tct  10    bertQPP            2   0.72  0.462424  0.000002
# 208       tct  10    bertQPP            2   0.82  0.449876  0.000004
#
#           tau   p1(tau)  num_of_queries
# 188  0.317010  0.000004              97
# 198  0.315292  0.000005              97
# 203  0.314003  0.000005              97
# 183  0.314003  0.000005              97
# 208  0.313574  0.000005              97

# %%
df[(df.alpha==0)&(df.window_size==2)]
# Out:
#   retriever   k   qpp_method  window_size  alpha         r     p1(r)  \
# 0       tct  10      spatial            2    0.0  0.033377  0.745518
# 1       tct  10      a_ratio            2    0.0  0.120325  0.240406
# 2       tct  10          nqc            2    0.0  0.137476  0.179334
# 3       tct  10      bertQPP            2    0.0  0.240609  0.017597
# 4       tct  10  bertQPP(QV)            2    0.0  0.227438  0.025064
#
#         tau   p1(tau)  num_of_queries
# 0  0.017182  0.803104              97
# 1  0.116838  0.089989              97
# 2  0.105241  0.126721              97
# 3  0.160653  0.019740              97
# 4  0.142182  0.039091              97

# %%
df[(df.alpha==1)&(df.qpp_method=='spatial')]
# Out:
#      retriever   k qpp_method  window_size  alpha         r     p1(r)  \
# 250        tct  10    spatial            2    1.0  0.370843  0.000185
# 505        tct  10    spatial            3    1.0  0.356591  0.000337
# 760        tct  10    spatial            4    1.0  0.350311  0.000435
# 1015       tct  10    spatial            5    1.0  0.314430  0.001709
# 1270       tct  10    spatial            6    1.0  0.292891  0.003598
# 1525       tct  10    spatial            7    1.0  0.339993  0.000656
# 1780       tct  10    spatial            8    1.0  0.323596  0.001224
# 2035       tct  10    spatial            9    1.0  0.251297  0.013032
# 2290       tct  10    spatial           10    1.0  0.259181  0.010362
# 2545       tct  10    spatial           11    1.0  0.275650  0.006280
# 2800       tct  10    spatial           12    1.0  0.269888  0.007508
# 3055       tct  10    spatial           13    1.0  0.270754  0.007311
# ...

# %%
df[(df.k==10)&(df.qpp_method=='nqc')].tau.values
# Out:
# array([], dtype=float64)
