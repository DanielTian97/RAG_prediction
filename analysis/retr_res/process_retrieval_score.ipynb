# %% [markdown]
# now all the monoT5 retrieval scores are in the style of the older pyterrier-T5 version [0, 1]

# %%
import numpy as np
import pandas as pd

_task = 'hotpotqa_dev'
retr_res = pd.read_csv(f'./mt5_{_task}.csv')
retr_res.score = retr_res.score.apply(lambda x: np.exp(x))
retr_res.to_csv(f'./mt5_{_task}.csv', index=False)
