# %%
import os
import pickle

import torch
import torch.nn.functional as F
from transformers import AutoModelForSequenceClassification, AutoTokenizer

# this part of code is duplicated from the work of https://github.com/jlko/semantic_uncertainty

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

class BaseEntailment:
    def save_prediction_cache(self):
        pass

class EntailmentDeberta(BaseEntailment):
    def __init__(self):
        self.tokenizer = AutoTokenizer.from_pretrained("microsoft/deberta-v2-xlarge-mnli", weights_only=False, truncation=True)
        # self.tokenizer = AutoTokenizer.from_pretrained("microsoft/deberta-v3-large")
        self.model = AutoModelForSequenceClassification.from_pretrained(
            "microsoft/deberta-v2-xlarge-mnli", weights_only=False).to(DEVICE)

    def check_implication(self, text1, text2, *args, **kwargs):
        # The model checks if text1 -> text2, i.e. if text2 follows from text1.
        # check_implication('The weather is good', 'The weather is good and I like you') --> 1
        # check_implication('The weather is good and I like you', 'The weather is good') --> 2

        torch.cuda.empty_cache()

        inputs = self.tokenizer(text1, text2, return_tensors="pt", max_length=150, truncation=True).to(DEVICE)

        outputs = self.model(**inputs)
        
        logits = outputs.logits
        
        class_scores = F.softmax(logits, dim=1)

        # Deberta-mnli returns `neutral` and `entailment` classes at indices 1 and 2.
        largest_index = torch.argmax(class_scores)  # pylint: disable=no-member
        prediction = largest_index.cpu().item()
        if os.environ.get('DEBERTA_FULL_LOG', False):
            logging.info('Deberta Input: %s -> %s', text1, text2)
            logging.info('Deberta Prediction: %s', prediction)

        del inputs
        del outputs
        del logits

        torch.cuda.empty_cache()

        return prediction, class_scores

    def get_entailment(self, text1, text2, *args, **kwargs):
        _, softmax_probs = self.check_implication(text1, text2, *args, **kwargs)
        torch.cuda.empty_cache()
        _entail_probs = [softmax_probs[i][2].cpu().detach().numpy().astype('float').item() for i in range(len(softmax_probs))]
        del softmax_probs
        return _entail_probs

# %%
try:
    del judger
except:
    print('first judger!')

judger = EntailmentDeberta()

# %%
try:
    torch.cuda.empty_cache()
    del x
    del y
except:
    print('x, y haven\'t been created yet.')
# Out:
# x, y haven't been created yet.

# %%
torch.cuda.empty_cache()

# %%
import pickle as pkl
import pandas as pd

f = open(f'../../rag_utility/doc_dicts/nq_wiki_dict.pkl', 'rb')
doc_dict = pkl.load(f)
f.close()

res = pd.read_csv(f'../../rag_utility/res/mt5_nq_test.csv')

def get_sentence_splitter():
    from sentence_splitter import SentenceSplitter
    _splitter = SentenceSplitter(language='en')
    return _splitter

# %%
from tqdm import tqdm

_k = 16

splitter = get_sentence_splitter()

# max_max_tokens = 0
# for _qid in tqdm(res.qid.unique()):
#     doc_texts = res[(res.qid == _qid) & (res['rank'] <_k)].docno.apply(lambda x: doc_dict[str(x)]).values
#     sentences = []
#     for doc_text in doc_texts:
#         sentences += splitter.split(doc_text)
#     for i in range(len(sentences)): # the last one don't need to be calculated
#         max_tokens = len(judger.tokenizer(sentences[i])['input_ids'])
#         # max_max_tokens = max(max_tokens, max_max_tokens)
#         if(max_tokens > 100):
#             print(_qid, sentences[i])
#     if(int(_qid.split('_')[1]) % 100 == 0):
#         print(max_max_tokens)
# print(max_max_tokens)

# %%
# torch.cuda.empty_cache()
# del x

# %%
# print(max(sum([len(i) for i in judger.tokenizer(sentences[i+1:i+1+batch_length])['input_ids']]), sum([len(i) for i in judger.tokenizer((batch_length)*[sentences[i]])['input_ids']])))

# %%
import timeit
import numpy as np

_k = 16

splitter = get_sentence_splitter()

doc_texts = res[(res.qid == 'test_225') & (res['rank'] <_k)].docno.apply(lambda x: doc_dict[str(x)]).values
sentences = []
for doc_text in doc_texts:
    sentences += splitter.split(doc_text)

print(f'totally {len(sentences)} sentences')

s = timeit.default_timer()
full_entail_matrix = []
for i in range(len(sentences)-1): # the last one don't need to be calculated
    batch_length = min(16, len(sentences)-i-1)   # only consider the sentences after it
    print(i, batch_length)
    # print(max(sum([len(j) for j in judger.tokenizer(sentences[i+1:i+1+batch_length])['input_ids']]), sum([len(j) for j in judger.tokenizer((batch_length)*[sentences[i]])['input_ids']])))
    x = judger.get_entailment(sentences[i+1:i+1+batch_length], (batch_length)*[sentences[i]])
    x = (i+1)*[-1] + x + (len(sentences)-i-1-len(x))*[-1]
    full_entail_matrix.append(x)
    torch.cuda.empty_cache()
    # print(x)
full_entail_matrix.append(len(sentences)*[-1])
e = timeit.default_timer()  
print(f'it took {e-s} seconds')
to_check = np.array(full_entail_matrix)
print(to_check.shape)
# Out:
# totally 80 sentences
# 0 16
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/miniconda3/envs/semantic_uncertainty_export/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:777, in BatchEncoding.convert_to_tensors(self, tensor_type, prepend_batch_axis)
#     776 if not is_tensor(value):
# --> 777     tensor = as_tensor(value)
#     779     # Removing this for now in favor of controlling the shape with `prepend_batch_axis`
#     780     # # at-least2d
#     781     # if tensor.ndim > 2:
#     782     #     tensor = tensor.squeeze(0)
#     783     # elif tensor.ndim < 2:
#     784     #     tensor = tensor[None, :]
#
# File /opt/miniconda3/envs/semantic_uncertainty_export/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:739, in BatchEncoding.convert_to_tensors.<locals>.as_tensor(value, dtype)
#     738     return torch.from_numpy(np.array(value))
# --> 739 return torch.tensor(value)
#
# ValueError: expected sequence of length 38 at dim 1 (got 23)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 21
#      19 print(i, batch_length)
#      20 # print(max(sum([len(j) for j in judger.tokenizer(sentences[i+1:i+1+batch_length])['input_ids']]), sum([len(j) for j in judger.tokenizer((batch_length)*[sentences[i]])['input_ids']])))
# ---> 21 x = judger.get_entailment(sentences[i+1:i+1+batch_length], (batch_length)*[sentences[i]])
#      22 x = (i+1)*[-1] + x + (len(sentences)-i-1-len(x))*[-1]
#      23 full_entail_matrix.append(x)
#
# Cell In[14], line 54, in EntailmentDeberta.get_entailment(self, text1, text2, *args, **kwargs)
#      53 def get_entailment(self, text1, text2, *args, **kwargs):
# ---> 54     _, softmax_probs = self.check_implication(text1, text2, *args, **kwargs)
#      55     torch.cuda.empty_cache()
#      56     _entail_probs = [softmax_probs[i][2].cpu().detach().numpy().astype('float').item() for i in range(len(softmax_probs))]
#
# Cell In[14], line 30, in EntailmentDeberta.check_implication(self, text1, text2, *args, **kwargs)
#      23 def check_implication(self, text1, text2, *args, **kwargs):
#      24     # The model checks if text1 -> text2, i.e. if text2 follows from text1.
#      25     # check_implication('The weather is good', 'The weather is good and I like you') --> 1
#      26     # check_implication('The weather is good and I like you', 'The weather is good') --> 2
#      28     torch.cuda.empty_cache()
# ---> 30     inputs = self.tokenizer(text1, text2, return_tensors="pt", max_length=150, truncation=True).to(DEVICE)
#      32     outputs = self.model(**inputs)
#      34     logits = outputs.logits
#
# File /opt/miniconda3/envs/semantic_uncertainty_export/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2887, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2885     if not self._in_target_context_manager:
#    2886         self._switch_to_input_mode()
# -> 2887     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2888 if text_target is not None:
#    2889     self._switch_to_target_mode()
#
# File /opt/miniconda3/envs/semantic_uncertainty_export/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:2975, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    2970         raise ValueError(
#    2971             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    2972             f" {len(text_pair)}."
#    2973         )
#    2974     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 2975     return self.batch_encode_plus(
#    2976         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2977         add_special_tokens=add_special_tokens,
#    2978         padding=padding,
#    2979         truncation=truncation,
#    2980         max_length=max_length,
#    2981         stride=stride,
#    2982         is_split_into_words=is_split_into_words,
#    2983         pad_to_multiple_of=pad_to_multiple_of,
#    2984         padding_side=padding_side,
#    2985         return_tensors=return_tensors,
#    2986         return_token_type_ids=return_token_type_ids,
#    2987         return_attention_mask=return_attention_mask,
#    2988         return_overflowing_tokens=return_overflowing_tokens,
#    2989         return_special_tokens_mask=return_special_tokens_mask,
#    2990         return_offsets_mapping=return_offsets_mapping,
#    2991         return_length=return_length,
#    2992         verbose=verbose,
#    2993         split_special_tokens=split_special_tokens,
#    2994         **kwargs,
#    2995     )
#    2996 else:
#    2997     return self.encode_plus(
#    2998         text=text,
#    2999         text_pair=text_pair,
#    (...)
#    3017         **kwargs,
#    3018     )
#
# File /opt/miniconda3/envs/semantic_uncertainty_export/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:3177, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3167 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3168 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3169     padding=padding,
#    3170     truncation=truncation,
#    (...)
#    3174     **kwargs,
#    3175 )
# -> 3177 return self._batch_encode_plus(
#    3178     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3179     add_special_tokens=add_special_tokens,
#    3180     padding_strategy=padding_strategy,
#    3181     truncation_strategy=truncation_strategy,
#    3182     max_length=max_length,
#    3183     stride=stride,
#    3184     is_split_into_words=is_split_into_words,
#    3185     pad_to_multiple_of=pad_to_multiple_of,
#    3186     padding_side=padding_side,
#    3187     return_tensors=return_tensors,
#    3188     return_token_type_ids=return_token_type_ids,
#    3189     return_attention_mask=return_attention_mask,
#    3190     return_overflowing_tokens=return_overflowing_tokens,
#    3191     return_special_tokens_mask=return_special_tokens_mask,
#    3192     return_offsets_mapping=return_offsets_mapping,
#    3193     return_length=return_length,
#    3194     verbose=verbose,
#    3195     split_special_tokens=split_special_tokens,
#    3196     **kwargs,
#    3197 )
#
# File /opt/miniconda3/envs/semantic_uncertainty_export/lib/python3.11/site-packages/transformers/tokenization_utils_fast.py:587, in PreTrainedTokenizerFast._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens)
#     585 for input_ids in sanitized_tokens["input_ids"]:
#     586     self._eventual_warn_about_too_long_sequence(input_ids, max_length, verbose)
# --> 587 return BatchEncoding(sanitized_tokens, sanitized_encodings, tensor_type=return_tensors)
#
# File /opt/miniconda3/envs/semantic_uncertainty_export/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:241, in BatchEncoding.__init__(self, data, encoding, tensor_type, prepend_batch_axis, n_sequences)
#     237     n_sequences = encoding[0].n_sequences
#     239 self._n_sequences = n_sequences
# --> 241 self.convert_to_tensors(tensor_type=tensor_type, prepend_batch_axis=prepend_batch_axis)
#
# File /opt/miniconda3/envs/semantic_uncertainty_export/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:793, in BatchEncoding.convert_to_tensors(self, tensor_type, prepend_batch_axis)
#     788         if key == "overflowing_tokens":
#     789             raise ValueError(
#     790                 "Unable to create tensor returning overflowing tokens of different lengths. "
#     791                 "Please see if a fast version of this tokenizer is available to have this feature available."
#     792             ) from e
# --> 793         raise ValueError(
#     794             "Unable to create tensor, you should probably activate truncation and/or padding with"
#     795             " 'padding=True' 'truncation=True' to have batched tensors with the same length. Perhaps your"
#     796             f" features (`{key}` in this case) have excessive nesting (inputs type `list` where type `int` is"
#     797             " expected)."
#     798         ) from e
#     800 return self
#
# ValueError: Unable to create tensor, you should probably activate truncation and/or padding with 'padding=True' 'truncation=True' to have batched tensors with the same length. Perhaps your features (`input_ids` in this case) have excessive nesting (inputs type `list` where type `int` is expected).

# %%
# import timeit

# text_0 = 'how is the weather?'
# text_1 = 'really sunny, isn\'t it?'

# s = timeit.default_timer()
# for i in range(100):
#     print(i)
#     x, y = judger.check_implication(50*[text_0], 50*[text_1])
#     del x
#     del y
#     torch.cuda.empty_cache()
# e = timeit.default_timer()  
# print(e-s)

# %%
# torch.cuda.empty_cache()
# del x
# del y
