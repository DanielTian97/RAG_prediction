# %%
import json

# %%
f = open('./dl_e5_20.json')
results = json.load(f)
f.close()
len(results)
# Out:
# 68

# %%
results
# Out:
# {'156493': {'0': -2.986328125,
#   '1': -2.830078125,
#   '2': -2.794921875,
#   '3': -3.033203125,
#   '4': -2.9375,
#   '5': -2.203125,
#   '6': -3.48046875,
#   '7': -3.015625,
#   '8': -2.56640625,
#   '9': -2.59765625,
#   '10': -3.576171875,
#   '11': -3.009765625,
#   '12': -2.916015625,
#   '13': -3.416015625,
#   '14': -2.71484375,
#   '15': -2.287109375,
#   '16': -2.212890625,
#   '17': -2.36328125,
#   '18': -2.47265625,
#   '19': -3.296875},
#  '1110199': {'0': -2.29296875,
#   '1': -3.1015625,
#   '2': -2.482421875,
#   '3': -2.615234375,
#   '4': -3.25390625,
#   '5': -2.1484375,
#   '6': -3.291015625,
#   '7': -3.263671875,
#   '8': -2.294921875,
#   '9': -2.376953125,
#   '10': -2.318359375,
#   '11': -2.45703125,
#   '12': -4.203125,
#   '13': -3.1015625,
#   '14': -2.990234375,
#   '15': -2.798828125,
#   '16': -3.4453125,
#   '17': -2.115234375,
#   '18': -3.076171875,
#   '19': -3.23828125},
#  '1063750': {'0': -3.34375,
#   '1': -3.39453125,
# ...
